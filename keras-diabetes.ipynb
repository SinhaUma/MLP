# %% [markdown]
# <a href="https://colab.research.google.com/github/SinhaUma/MLP/blob/main/keras-diabetes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r'/content/diabetes.csv')

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
x= data.iloc[:,:3]
y=data.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test= train_test_split(x,y,random_state=42,test_size=0.2)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_trainscaled=scaler.fit_transform(X_train)
X_testscaled=scaler.transform(X_test)

# %%
from tensorflow.keras.utils import to_categorical
y_train_ohe = to_categorical(y_train)
y_test_ohe = to_categorical(y_test)

# %%
print(X_trainscaled.shape)
print(X_testscaled.shape)
print(y_train_ohe.shape)
print(y_test_ohe.shape)
# Out:
# (614, 3)
# (154, 3)
# (614, 2)
# (154, 2)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.optimizers import Adam

# %%
model =Sequential()
model.add(Input(3))
model.add(Dense(units=8,activation="relu"))
model.add(Dense(2, activation="sigmoid"))

# %%
model.compile(optimizer="SGD",loss="binary_crossentropy",metrics=["accuracy"])

# %%
model.fit(X_trainscaled, y_train_ohe, epochs=100, batch_size=10,validation_data=(X_testscaled, y_test_ohe))
# Out:
# Epoch 1/100
# 62/62 [==============================] - 1s 5ms/step - loss: 0.6490 - accuracy: 0.6873 - val_loss: 0.6539 - val_accuracy: 0.7078
# Epoch 2/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.6337 - accuracy: 0.7101 - val_loss: 0.6390 - val_accuracy: 0.7078
# Epoch 3/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.6214 - accuracy: 0.7199 - val_loss: 0.6267 - val_accuracy: 0.7078
# Epoch 4/100
# 62/62 [==============================] - 0s 3ms/step - loss: 0.6113 - accuracy: 0.7248 - val_loss: 0.6152 - val_accuracy: 0.7208
# Epoch 5/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.6019 - accuracy: 0.7296 - val_loss: 0.6053 - val_accuracy: 0.7338
# Epoch 6/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5937 - accuracy: 0.7296 - val_loss: 0.5968 - val_accuracy: 0.7338
# Epoch 7/100
# ...

# %%
X = data.iloc[:,:-1]
y = data.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test= train_test_split(X,y,random_state=42,test_size=0.2)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_trainscaled=scaler.fit_transform(X_train)
X_testscaled=scaler.transform(X_test)

# %%
from tensorflow.keras.utils import to_categorical
y_train_ohe = to_categorical(y_train)
y_test_ohe = to_categorical(y_test)

# %%
print(X_trainscaled.shape)
print(X_testscaled.shape)
print(y_train_ohe.shape)
print(y_test_ohe.shape)
# Out:
# (614, 8)
# (154, 8)
# (614, 2)
# (154, 2)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.optimizers import Adam

# %%
model =Sequential()
model.add(Input(8))
model.add(Dense(units=16,activation="relu"))
model.add(Dense(units=16,activation="relu"))
model.add(Dense(units=16,activation="relu"))
model.add(Dense(2, activation="sigmoid"))

# %%
model.compile(optimizer="Adam",loss="binary_crossentropy",metrics=["accuracy"])

# %%
model.fit(X_trainscaled, y_train_ohe, epochs=150, batch_size=10,validation_data=(X_testscaled, y_test_ohe))
# Out:
# Epoch 1/150
# 62/62 [==============================] - 1s 6ms/step - loss: 0.6658 - accuracy: 0.6384 - val_loss: 0.6311 - val_accuracy: 0.7208
# Epoch 2/150
# 62/62 [==============================] - 0s 2ms/step - loss: 0.6096 - accuracy: 0.7443 - val_loss: 0.5845 - val_accuracy: 0.7532
# Epoch 3/150
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5497 - accuracy: 0.7524 - val_loss: 0.5373 - val_accuracy: 0.7727
# Epoch 4/150
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5019 - accuracy: 0.7622 - val_loss: 0.5082 - val_accuracy: 0.7792
# Epoch 5/150
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4730 - accuracy: 0.7687 - val_loss: 0.4985 - val_accuracy: 0.7662
# Epoch 6/150
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4573 - accuracy: 0.7687 - val_loss: 0.4953 - val_accuracy: 0.7792
# Epoch 7/150
# ...

# %% [markdown]
# In the first case model accuracy is 73.13%.
# In the second case it is 92.83%.
